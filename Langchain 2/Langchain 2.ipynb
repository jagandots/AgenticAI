# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import CSVLoader

# %%
loader = PyMuPDFLoader("car101.pdf")

# %%
docs = loader.load()
docs[0]
# Out:
# Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 0}, page_content='Cars 101\nIntimidated by your car? Afraid to peek under the hood and face the \nbeast that carries you down life’s highway? Don’t be! Cars actually work \non simple principles. If you know how they do their magic, you can con-\ntrol them better. And you can make them more fuel efficient. This first \nchapter gives you a good look under the hood, showing you how things \nwork—and what to do when they don’t. Starting now, you will never be \nfrightened by your car—or your mechanic—again.\nchapter 1\nCOPYRIGHTED MATERIAL')

# %%
import pprint

pprint.pp(docs[0].metadata)
# Out:
# {'producer': 'Acrobat Distiller 6.0.1 (Windows)',
#  'creator': 'Adobe InDesign CS3 (5.0.3)',
#  'creationdate': '2009-01-30T20:33:37-05:00',
#  'source': 'car101.pdf',
#  'file_path': 'car101.pdf',
#  'total_pages': 14,
#  'format': 'PDF 1.3',
#  'title': '03_377277-ch01.indd',
#  'author': 'jturner',
#  'subject': '',
#  'keywords': '',
#  'moddate': "D:20090515084136-04'",
#  'trapped': '',
#  'modDate': "D:20090515084136-04'",
#  'creationDate': "D:20090130203337-05'00'",
#  'page': 0}

# %%
loader = CSVLoader("weather_info.csv")
data = loader.load()
pprint.pp(data)
# Out:
# [Document(metadata={'source': 'weather_info.csv', 'row': 0}, page_content='ï»¿hours_sunlight: 10.5\nhumidity_level: 65\ndaily_temperature: 22.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 1}, page_content='ï»¿hours_sunlight: 9.2\nhumidity_level: 70\ndaily_temperature: 21'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 2}, page_content='ï»¿hours_sunlight: 7.8\nhumidity_level: 80\ndaily_temperature: 18.5'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 3}, page_content='ï»¿hours_sunlight: 6.4\nhumidity_level: 90\ndaily_temperature: 17.2'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 4}, page_content='ï»¿hours_sunlight: 8.1\nhumidity_level: 75\ndaily_temperature: 19.4'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 5}, page_content='ï»¿hours_sunlight: 11\nhumidity_level: 60\ndaily_temperature: 24'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 6}, page_content='ï»¿hours_sunlight: 5.5\nhumidity_level: 85\ndaily_temperature: 16'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 7}, page_content='ï»¿hours_sunlight: 9.8\nhumidity_level: 68\ndaily_temperature: 21.7'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 8}, page_content='ï»¿hours_sunlight: 7.2\nhumidity_level: 77\ndaily_temperature: 19'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 9}, page_content='ï»¿hours_sunlight: 6\nhumidity_level: 88\ndaily_temperature: 17'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 10}, page_content='ï»¿hours_sunlight: 8.7\nhumidity_level: 72\ndaily_temperature: 20.2'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 11}, page_content='ï»¿hours_sunlight: 10\nhumidity_level: 66\ndaily_temperature: 22.5'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 12}, page_content='ï»¿hours_sunlight: 4.3\nhumidity_level: 92\ndaily_temperature: 15'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 13}, page_content='ï»¿hours_sunlight: 7.5\nhumidity_level: 78\ndaily_temperature: 18.7'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 14}, page_content='ï»¿hours_sunlight: 6.8\nhumidity_level: 83\ndaily_temperature: 17.5'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 15}, page_content='ï»¿hours_sunlight: 11.2\nhumidity_level: 62\ndaily_temperature: 24.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 16}, page_content='ï»¿hours_sunlight: 5.9\nhumidity_level: 89\ndaily_temperature: 16.8'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 17}, page_content='ï»¿hours_sunlight: 8.3\nhumidity_level: 74\ndaily_temperature: 19.6'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 18}, page_content='ï»¿hours_sunlight: 9\nhumidity_level: 71\ndaily_temperature: 20.8'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 19}, page_content='ï»¿hours_sunlight: 7\nhumidity_level: 82\ndaily_temperature: 18.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 20}, page_content='ï»¿hours_sunlight: 10.1\nhumidity_level: 64\ndaily_temperature: 22.7'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 21}, page_content='ï»¿hours_sunlight: 8.6\nhumidity_level: 73\ndaily_temperature: 20.1'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 22}, page_content='ï»¿hours_sunlight: 6.5\nhumidity_level: 87\ndaily_temperature: 17.1'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 23}, page_content='ï»¿hours_sunlight: 9.5\nhumidity_level: 69\ndaily_temperature: 21.2'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 24}, page_content='ï»¿hours_sunlight: 7.3\nhumidity_level: 79\ndaily_temperature: 18.8'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 25}, page_content='ï»¿hours_sunlight: 5.4\nhumidity_level: 86\ndaily_temperature: 16.2'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 26}, page_content='ï»¿hours_sunlight: 10.8\nhumidity_level: 61\ndaily_temperature: 23.8'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 27}, page_content='ï»¿hours_sunlight: 8.9\nhumidity_level: 70\ndaily_temperature: 20.9'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 28}, page_content='ï»¿hours_sunlight: 6.7\nhumidity_level: 84\ndaily_temperature: 17.4'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 29}, page_content='ï»¿hours_sunlight: 9.1\nhumidity_level: 72\ndaily_temperature: 21'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 30}, page_content='ï»¿hours_sunlight: 11.1\nhumidity_level: 63\ndaily_temperature: 24.1'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 31}, page_content='ï»¿hours_sunlight: 5.8\nhumidity_level: 88\ndaily_temperature: 16.7'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 32}, page_content='ï»¿hours_sunlight: 8.4\nhumidity_level: 74\ndaily_temperature: 19.7'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 33}, page_content='ï»¿hours_sunlight: 7.1\nhumidity_level: 81\ndaily_temperature: 18.4'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 34}, page_content='ï»¿hours_sunlight: 10.2\nhumidity_level: 65\ndaily_temperature: 22.4'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 35}, page_content='ï»¿hours_sunlight: 6.6\nhumidity_level: 85\ndaily_temperature: 17.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 36}, page_content='ï»¿hours_sunlight: 9.7\nhumidity_level: 67\ndaily_temperature: 21.5'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 37}, page_content='ï»¿hours_sunlight: 7.4\nhumidity_level: 78\ndaily_temperature: 18.6'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 38}, page_content='ï»¿hours_sunlight: 6.1\nhumidity_level: 86\ndaily_temperature: 16.9'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 39}, page_content='ï»¿hours_sunlight: 8.8\nhumidity_level: 73\ndaily_temperature: 20.5'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 40}, page_content='ï»¿hours_sunlight: 10.3\nhumidity_level: 64\ndaily_temperature: 22.6'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 41}, page_content='ï»¿hours_sunlight: 5.7\nhumidity_level: 89\ndaily_temperature: 16.6'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 42}, page_content='ï»¿hours_sunlight: 7.6\nhumidity_level: 76\ndaily_temperature: 18.9'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 43}, page_content='ï»¿hours_sunlight: 9.3\nhumidity_level: 71\ndaily_temperature: 21.1'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 44}, page_content='ï»¿hours_sunlight: 10.9\nhumidity_level: 62\ndaily_temperature: 23.9'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 45}, page_content='ï»¿hours_sunlight: 6.2\nhumidity_level: 84\ndaily_temperature: 17'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 46}, page_content='ï»¿hours_sunlight: 8.2\nhumidity_level: 75\ndaily_temperature: 19.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 47}, page_content='ï»¿hours_sunlight: 9.4\nhumidity_level: 70\ndaily_temperature: 21.3'),
#  Document(metadata={'source': 'weather_info.csv', 'row': 48}, page_content='ï»¿hours_sunlight: 7.9\nhumidity_level: 77\ndaily_temperature: 19.1')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100,
)
texts = text_splitter.split_documents(docs)
pprint.pp(texts)
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 0}, page_content='Cars 101\nIntimidated by your car? Afraid to peek under the hood and face the \nbeast that carries you down life’s highway? Don’t be! Cars actually work \non simple principles. If you know how they do their magic, you can con-\ntrol them better. And you can make them more fuel efficient. This first \nchapter gives you a good look under the hood, showing you how things \nwork—and what to do when they don’t. Starting now, you will never be \nfrightened by your car—or your mechanic—again.\nchapter 1'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 0}, page_content='frightened by your car—or your mechanic—again.\nchapter 1\nCOPYRIGHTED MATERIAL'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 1}, page_content='How Cars Work . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 4\nGas Station Wisdom. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7\nThe Secret of Auto Repair . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 10\nDo-It-Yourself or Not? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12\nFinding a Mechanic  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 1}, page_content='Finding a Mechanic  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13\nCar Computer Basics  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 14'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 2}, page_content='4\nAn automobile is a self-propelled (auto) vehicle (mobile). The modern automobile design dates back 120 years to when \ngasoline-fueled engines were installed in carriages formerly pulled by horses. Soon, other components were added to make \nthe ride smoother, faster, and more enjoyable for passengers. Within 25 years, more than 1 million cars and trucks were on \nthe roads and the horse was nearly unemployed.\nAutomobile History 101'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 2}, page_content='the roads and the horse was nearly unemployed.\nAutomobile History 101\nCars are seemingly complex, and becoming more so every day. However, they operate based on prin-\nciples that everyone can understand.\nHow Cars \nWork'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}, page_content='chapter1\nCars 101\n5\nENGINE\nThe engine in a car contains cylinders in which thousands of con-\ntrolled explosions occur every minute the engine is running. The \nexplosions occur when a mixture of gasoline and air is com-\npressed and then ignited by an electric spark. The resulting explo-\nsions push the movable bottom wall of the cylinder down, which \nturns a shaft.\nPrimary Automobile Components\nSpark\nplug\nExhaust\nvalve\nIntake\nvalve\nCombustion\nchamber\nPiston\nCrankshaft\nAir and\ngasoline\nTRANSMISSION'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}, page_content='plug\nExhaust\nvalve\nIntake\nvalve\nCombustion\nchamber\nPiston\nCrankshaft\nAir and\ngasoline\nTRANSMISSION\nA transmission transmits or moves the engine’s rotation power to the wheels in stages using gears. Transmission gears func-\ntion similarly to the gears on a ten-speed bicycle. A manual transmission requires the driver to manually select gears, while \nan automatic transmission selects gears automatically as designed.\nEngine\nFlywheel\nPressure\nplate\nClutch pedal\nManual Transmission\nOutput\nshaft'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}, page_content='Engine\nFlywheel\nPressure\nplate\nClutch pedal\nManual Transmission\nOutput\nshaft\nDrive-\nshaft\nCrankshaft\nClutch\ndisk\nInput\nshaft\nThrow-out\nbearing\nGears\nU-Joints\nGearshift\nDiﬀerential\nRear\naxle\nCONTINUED ON NEXT PAGE'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 4}, page_content='6\nSUPPORTING SYSTEMS\nEverything else in your car supports either the engine and transmission or passenger comfort. To fulfill its function, your car \nneeds:\nHow Cars \nWork (continued)\n• Cooling and lubrication (Chapter 4)\n• Electricity (Chapter 5)\n• Fuel (Chapter 6)\n• Wheels and tires (Chapter 7)\n• Brakes (Chapter 8)\n• Body (Chapter 10)\nTIP\nYour Car’s Book\nFor more specific information on your car, read the owner’s man-\nual that’s probably in the glove compartment. Also, consider buy-'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 4}, page_content='ual that’s probably in the glove compartment. Also, consider buy-\ning a repair manual from the manufacturer or an after-market \npublisher such as Chilton or Haynes, available at larger book-\nstores.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}, page_content='chapter1\nCars 101\n7\nSELECT FUEL\nMost fuel stations offer three grades of gasoline, and some also have one grade of diesel fuel. Gas energy is measured in \nminimum octane ratings—87, 89, and 91—marked clearly on the pumps. Which grade should your car use?\nAll gas-engine cars can operate using 87-octane gasoline, the least expensive grade. Some high-performance engines operate'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}, page_content='more efficiently with higher grade fuel. Your car’s owner’s manual will indicate which grade of gas the engine was designed \nto operate on. Alternately, use 87 octane unless the running engine has a pinging sound, called knocking, that may damage \nan engine. Then use higher octane fuel that doesn’t knock.\nDiesel is also a petroleum fuel, but not the same as gasoline. Don’t use diesel in a gas engine or vice versa. Note that No. 2 \ndiesel is pumped from a green nozzle.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}, page_content='diesel is pumped from a green nozzle.\nChecking Out Your Car While Working the Pump\nThe best place to start getting to know your car is at the gas station. Take the time while the gas is \npumping to distract yourself from the cost and spend some quality time with your car.\nWhat can you do at the pumps? You can select the most appropriate fuel for your car, check fluid \nlevels, do a visual inspection, and make sure that all systems are “go” before pulling back onto the \nhighway.\nGas Station'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}, page_content='highway.\nGas Station \nWisdom\nCONTINUED ON NEXT PAGE'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}, page_content='8\nPOP THE HOOD\nFor safety and security, the engine cover, called the hood (or \nbonnet in Britain), is latched into place. The hood release latch \ntypically is located under the left side of the dashboard and is \noften marked HOOD.\n1 Pull the hood lever inside the car.\n2 Reach under the center of the partially opened hood and move \nthe safety lever. (The car’s owner’s manual offers the specific \nlocation and instructions.)\n3 Lift the hood and secure it in place. Many modern cars have a'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}, page_content='location and instructions.)\n3 Lift the hood and secure it in place. Many modern cars have a \nmetal support bar across the front of the engine compartment. \nLift the bar into place and insert the end into the designated \nhole on the bottom side of the hood.\n4 Check the levels of engine oil and other liquids as described \nlater in this book.\n5 Perform a visual inspection for any obvious liquid leaks, rodent nests, loose caps, or other potential problems.\nWALK AROUND'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}, page_content='WALK AROUND\nOnce you’ve firmly closed the hood, walk around the car, \ninspecting the tires and underside for obvious problems or \nleaks. Inspect tires for wear, especially uneven wear, as \ndescribed in Chapter 7 on suspension systems.\nGas Station \nWisdom (continued)'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}, page_content='chapter1\nCars 101\n9\nREAD THE GAUGES\nYour car has numerous lights and gauges that continually report the condition of its components. To read them, start the car \nor turn the ignition to the ACCESSORIES position.\n • Ammeter gauge or light reports on how well the battery is being recharged by the alternator.\n • Temperature gauge or light tells you if the engine is operating too hot. \n • Fuel gauge indicates the level of fuel in the tank(s).'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}, page_content='• Fuel gauge indicates the level of fuel in the tank(s).\nYou will learn to read and interpret these gauges as well as the car’s computer in coming chapters.\nCheck engine\nTachometer\nAmmeter\nOdometer\nCredit: American Honda Corp.\nFuel\nTemperature\nOil\nSpeedometer\nTIP\nUse Your Senses\nIn addition to looking at your car, pay attention to smells under the hood. The smells of burned rub-\nber or plastic or of leaking fuel are warning signs that can alert you to potential problems. Also, listen'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}, page_content='to your car when it’s running well so that you’ll recognize the sound when it doesn’t run well.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}, page_content='10\nPREVENTIVE MAINTENANCE\nAn important step in owning a trouble-free car—and minimizing costly work—is preventive maintenance. Replace oil, filters, \nand tires before they wear out and cause further damage. This book shows you how to perform basic preventive mainte-\nnance on your car step by step. Automotive maintenance is easy—when you know how.\nOBSERVE\nModern cars are easier to drive; however, drivers today also have more'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}, page_content='OBSERVE\nModern cars are easier to drive; however, drivers today also have more \ndistractions, such as cell phones, GPS, and the radio. Beginning at the gas \nstation and continuing every mile that you drive, pay close attention to \nyour car. As you learn more about how it works in this book, you’ll detect \nmore of the telltale signs that indicate what is expected and what is a \npotential problem.\nKnowing Your Car’s Needs'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}, page_content='potential problem.\nKnowing Your Car’s Needs\nThe complexity of cars over the past century, such as computer-controlled electrical systems, makes \ntaking things apart and repairing them more difficult.\nFortunately, you don’t have to rebuild a component anymore. It’s easier—and often cheaper—\nto simply replace the part. In fact, that’s what auto mechanics usually do. They replace rather than \nrepair defective parts, and so can you, which is the secret of modern auto repair.\nThe Secret of'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}, page_content='repair defective parts, and so can you, which is the secret of modern auto repair.\nThe Secret of \nAuto Repair\nREPLACE\nReplacing a defective part can be a relatively simple job, depending on \nhow difficult it is to get to the problem part. Many automotive parts can be \nreplaced by any car owner. Others require additional instruction from this \nbook or a specific-model repair manual. Still others are most efficiently \nreplaced by a trained mechanic who has the tools and knowledge to'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}, page_content='replaced by a trained mechanic who has the tools and knowledge to \nmake a difficult job look easy. This book helps you identify what you can \nreplace and what you can’t.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='chapter1\nCars 101\n11\nTROUBLESHOOT\nTroubleshooting is simply comparing what you see to what you expect to \nsee, and then using your knowledge to identify the cause. For example, you \nobserve that the engine doesn’t start as easily on mornings after it hasn’t \nbeen driven for a few days. Knowing how cars work, you believe that a \nslow leak in a fuel line is robbing the engine of needed fuel when it starts \nup. A quick inspection confirms your observation and you have solved the'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='up. A quick inspection confirms your observation and you have solved the \nproblem—and saved yourself some money and future problems.\nTIP\nTroubleshooting Charts\nA troubleshooting chart can save you hours of \nwork and many dollars in replacement parts by \nhelping you identify the source of an automo-\ntive problem. Your car’s repair manual includes \ntroubleshooting tips specific to the make, \nmodel, design, and components of your car. If \nthe chart indicates more than one option, per-'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='model, design, and components of your car. If \nthe chart indicates more than one option, per-\nform the easiest or least expensive before trying \nthe others.\nSTEERING SYSTEM PROBLEMS\nCONDITION\nPower\nsteering \npump leaks.\nNoise in\nsteering\ncolumn.\n(Squeak\nor creak)\n(Clunk)\nExcessive\nSteering \nEﬀort\n1. Fluid, cap and dipstick.\n1. Check for indications of false leakage — \noverﬁlled reservoir, improperly installed, \ndamaged or lost cap or dipstick.\n2. Loose or damaged hose connections.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='damaged or lost cap or dipstick.\n2. Loose or damaged hose connections.\n2. Repair or replace as required.\n3. Leakage between reservoir and housing.\n3. Repair or replace as required.\n4. Leakage at pump shaft seal area.\n4. Replace shaft seal or pump.\n1. Steering column cover interference.\n1.  Adjust or reposition as required.\n2. Steering column out of alignment.\n2. Align or adjust as required.\n3. Lack of lubrication where horn brush contacts rub\nplate of steering wheel.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='3. Lack of lubrication where horn brush contacts rub\nplate of steering wheel.\n3. Lube or adjust as required.\n4. Loose steering column mounting bolts.\n4. Tighten to speciﬁcation.\n5. Flex coupling bottoming.\n5. Align or adjust as required.\n6. Loose pot coupling to steering column bolt.\n6. Tighten to speciﬁcation.\n7. Improper steering gear mesh load.\n7. Readjust to speciﬁcation.\n1. Improper oversized tires.\n1. Install correct tire and wheel combination. \n2. Tires not uniform.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='1. Improper oversized tires.\n1. Install correct tire and wheel combination. \n2. Tires not uniform.\n2. Install correct tire and wheel combination. \n3. Tire pressure.\n3. Adjust air pressure in tires.\n4. Misaligned ﬂexible coupling (if so equipped) to\ngear interference.\n4. Align or adjust as required. \n5. Steering wheel to column interference.\n5. Align or adjust as required. \n6.  Steering column alignment\n6. Align or adjust as required (E-150 — E-350).'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}, page_content='6.  Steering column alignment\n6. Align or adjust as required (E-150 — E-350).\n7. Steering linkage or front axle spindle pins for a\nbinding condition or lack of lubrication.\n7.  Lube, inspect, adjust o replace as required.\n8. Bind in front axle spindle thrust bearings.\n8. Lube, inspect, adjust or replace as required.\n9. Steering gear adjustment.\n9. Adjust to speciﬁcation.\nPOSSIBLE CAUSE\nRESOLUTION'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}, page_content='12\nKNOWLEDGE\nThe primary difference between you and a $90+-an-hour auto mechanic is knowledge. The mechanic has gone to school to \nlearn about how cars run, diagnostics, and parts replacement. You can pick up the knowledge needed for basic car care and \nmaintenance from this book. With experience, you may decide to tackle increasingly complex repairs on your car. Car care'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}, page_content='isn’t an all-or-nothing task. You can do the jobs that you are comfortable with and leave the heavy lifting to your well-chosen \nmechanic.\nTOOLS\nAnother clear difference between \nmechanics and the typical car owner is \ntools. A mechanic or repair shop has \nthousands of dollars invested in special-\nized tools and diagnostic equipment, \nwhile the owner may have a $50 tool-\nbox. Fortunately, you often can rent \nmore expensive tools for difficult jobs.\nThe bottom line is that you have'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}, page_content='more expensive tools for difficult jobs.\nThe bottom line is that you have \noptions. You can take better care of \nyour car—and be ready to handle prob-\nlems—by learning more about your car \nand performing increasingly difficult \njobs.\nIntimidated by the complexity of taking care of your car? Don’t be. Owners have been successfully \nmaintaining and repairing their cars for decades. In a couple of pages, you’ll learn how trouble-'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}, page_content='maintaining and repairing their cars for decades. In a couple of pages, you’ll learn how trouble-\nshooting and making repairs is even easier than it was two decades ago. You just need knowledge \nand the proper tools.\nDo-It-Yourself \nor Not?'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}, page_content='chapter1\nCars 101\n13\nStart looking for a fair and competent \nmechanic as you take on more respon-\nsibility for the care of your car. As you \nlearn more about how your car operates \nand how to diagnose problems, you’ll \nalso learn more about mechanics. The \nmore you know about how your car \nworks, the easier it will be to recognize \na trustworthy mechanic. You’ll discover \nthat most are specialized: One who may \nbe specially trained in automatic trans-\nmissions probably doesn’t know as'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}, page_content='be specially trained in automatic trans-\nmissions probably doesn’t know as \nmuch about fuel injection systems.\nThe National Institute for Automotive \nService Excellence (ASE) and other trade \ngroups offer courses and certification \ntests for automotive technicians and \nparts clerks. An ASE mechanic who is \ncertified in all car systems earns the \nMaster Mechanic designation. Of course, \nif you need only a qualified transmission \nmechanic, you can select one with ASE'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}, page_content='if you need only a qualified transmission \nmechanic, you can select one with ASE \ncertification in transmissions rather than one who does all repairs. Also, some repair shops earn AAA approval.\nKnowing When You’ve Found “The One”\nWhere is a qualified and honest mechanic when you need one? Well, the best time to find one is \nwhen you don’t need one and when your car doesn’t have an emergency that needs to be taken \ncare of. \nFinding a \nMechanic\nTIP\nCompare Shop Rates'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}, page_content='care of. \nFinding a \nMechanic\nTIP\nCompare Shop Rates\nMany auto mechanics estimate the \ntime required to complete a repair by \nusing recommendations in a flat rate \nmanual. They multiply the time esti-\nmate by their hourly shop rate to \ndetermine the labor rate. The higher \nthe shop rate, the more expensive the \nlabor charge will be.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}, page_content='14\nWHAT IS OBD-II?\nAll new cars, light trucks, SUVs, and minivans sold in North \nAmerica since 1996 are required to have a connection for on-\nboard diagnostics (OBD). The second version, OBD-II, has \nbeen the standard for more than a decade. Europe has had \nEOBD for new gasoline cars since 2001 and diesel cars since \n2004.\nOBD-readers plug into a connection on the vehicle, read the \ncomputer data, and report parameter identification numbers'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}, page_content='computer data, and report parameter identification numbers \n(PIDs). These PIDs can be decoded. P1456, for example, indi-\ncates that an EVAP system leak is detected in the fuel tank \narea. In plain English, the gas cap is loose. Mechanics have \nbeen using on-board diagnostics readers for many years.\nOBD-II\nWouldn’t it be great if you could read the mind of your car’s computer, just like your mechanic does \nwith engine-analysis tools? You can!\nCar Computer \nBasics\nFINDING OBD-II DIAGNOSTICS TOOLS'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}, page_content='with engine-analysis tools? You can!\nCar Computer \nBasics\nFINDING OBD-II DIAGNOSTICS TOOLS\nThe good news for consumers is that handheld OBD-II diag-\nnostics tools are now available for less than $100! One popu-\nlar version is the CarMD (www.carmd.com). With the included \ninstructions and software, car owners can read and interpret \nthe car’s diagnostics system. You can use these handy tools to:\n • Quickly diagnose problems during an emergency.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}, page_content='• Quickly diagnose problems during an emergency.\n • Discuss an automotive problem more accurately with \nyour mechanic.\n • Verify the findings of your mechanic.\n • Check your car for problems before taking it in for a \nstate-required smog test.\n • Check cars and light trucks you are considering for pur-\nchase.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}, page_content='chapter1\nCars 101\n15\nUSING THE OBD-II\nThere are four simple steps to using a consumer-level OBD-II \ndiagnostics tool:\n1 Insert the data link connector (DLC) into the car’s receptacle. \n(Check your car owner’s manual for the DLC location.)\n2 Within 10 seconds, turn the ignition key to the \x01\x02 (not \x03\x04\x05\x06\x04) \nposition.\n3 Wait for the data download to complete.\n4 Refer to the tool’s printed documentation, computer software, \nor website to decode the data.'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}, page_content='4 Refer to the tool’s printed documentation, computer software, \nor website to decode the data.\nChapter 5 offers more detailed steps for using a consumer \nOBD-II diagnostics tool. Also refer to instructions that come \nwith the unit. \nFAQ \nHow can I know for sure if my \ncar’s computer can be read by \nOBD-II analyzers?\nAll 1996 and newer vehicles are \nrequired to be OBD-II (also known as \nOBD2) compliant. In addition, some \n1994 and 1995 cars can be read by'),
#  Document(metadata={'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}, page_content='OBD2) compliant. In addition, some \n1994 and 1995 cars can be read by \nOBD-II analyzers. To verify, open your \ncar’s hood and look for the VEHICLE \nEMISSION CONTROL INFORMATION label \nlocated on the underside of the hood \nor near the radiator. If it is compliant, \nthe label will say “OBD-II Certified.” \nSome light-duty diesel pickup trucks \nand recreational vehicles (RVs) also \nare OBD-II certified.')]

# %%
for i, text in enumerate(texts):
    print(f"Text {i}:")
    print(text.page_content)
    print("Metadata:", text.metadata)
    print("-" * 40)
# Out:
# Text 0:
# Cars 101
# Intimidated by your car? Afraid to peek under the hood and face the
# beast that carries you down life’s highway? Don’t be! Cars actually work
# on simple principles. If you know how they do their magic, you can con-
# trol them better. And you can make them more fuel efficient. This first
# chapter gives you a good look under the hood, showing you how things
# work—and what to do when they don’t. Starting now, you will never be
# frightened by your car—or your mechanic—again.
# chapter 1
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 0}
# ----------------------------------------
# Text 1:
# frightened by your car—or your mechanic—again.
# chapter 1
# COPYRIGHTED MATERIAL
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 0}
# ----------------------------------------
# Text 2:
# How Cars Work . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 4
# Gas Station Wisdom. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7
# The Secret of Auto Repair . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 10
# Do-It-Yourself or Not? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 12
# Finding a Mechanic  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 1}
# ----------------------------------------
# Text 3:
# Finding a Mechanic  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13
# Car Computer Basics  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 14
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 1}
# ----------------------------------------
# Text 4:
# 4
# An automobile is a self-propelled (auto) vehicle (mobile). The modern automobile design dates back 120 years to when
# gasoline-fueled engines were installed in carriages formerly pulled by horses. Soon, other components were added to make
# the ride smoother, faster, and more enjoyable for passengers. Within 25 years, more than 1 million cars and trucks were on
# the roads and the horse was nearly unemployed.
# Automobile History 101
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 2}
# ----------------------------------------
# Text 5:
# the roads and the horse was nearly unemployed.
# Automobile History 101
# Cars are seemingly complex, and becoming more so every day. However, they operate based on prin-
# ciples that everyone can understand.
# How Cars
# Work
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 2}
# ----------------------------------------
# Text 6:
# chapter1
# Cars 101
# 5
# ENGINE
# The engine in a car contains cylinders in which thousands of con-
# trolled explosions occur every minute the engine is running. The
# explosions occur when a mixture of gasoline and air is com-
# pressed and then ignited by an electric spark. The resulting explo-
# sions push the movable bottom wall of the cylinder down, which
# turns a shaft.
# Primary Automobile Components
# Spark
# plug
# Exhaust
# valve
# Intake
# valve
# Combustion
# chamber
# Piston
# Crankshaft
# Air and
# gasoline
# TRANSMISSION
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}
# ----------------------------------------
# Text 7:
# plug
# Exhaust
# valve
# Intake
# valve
# Combustion
# chamber
# Piston
# Crankshaft
# Air and
# gasoline
# TRANSMISSION
# A transmission transmits or moves the engine’s rotation power to the wheels in stages using gears. Transmission gears func-
# tion similarly to the gears on a ten-speed bicycle. A manual transmission requires the driver to manually select gears, while
# an automatic transmission selects gears automatically as designed.
# Engine
# Flywheel
# Pressure
# plate
# Clutch pedal
# Manual Transmission
# Output
# shaft
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}
# ----------------------------------------
# Text 8:
# Engine
# Flywheel
# Pressure
# plate
# Clutch pedal
# Manual Transmission
# Output
# shaft
# Drive-
# shaft
# Crankshaft
# Clutch
# disk
# Input
# shaft
# Throw-out
# bearing
# Gears
# U-Joints
# Gearshift
# Diﬀerential
# Rear
# axle
# CONTINUED ON NEXT PAGE
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 3}
# ----------------------------------------
# Text 9:
# 6
# SUPPORTING SYSTEMS
# Everything else in your car supports either the engine and transmission or passenger comfort. To fulfill its function, your car
# needs:
# How Cars
# Work (continued)
# • Cooling and lubrication (Chapter 4)
# • Electricity (Chapter 5)
# • Fuel (Chapter 6)
# • Wheels and tires (Chapter 7)
# • Brakes (Chapter 8)
# • Body (Chapter 10)
# TIP
# Your Car’s Book
# For more specific information on your car, read the owner’s man-
# ual that’s probably in the glove compartment. Also, consider buy-
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 4}
# ----------------------------------------
# Text 10:
# ual that’s probably in the glove compartment. Also, consider buy-
# ing a repair manual from the manufacturer or an after-market
# publisher such as Chilton or Haynes, available at larger book-
# stores.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 4}
# ----------------------------------------
# Text 11:
# chapter1
# Cars 101
# 7
# SELECT FUEL
# Most fuel stations offer three grades of gasoline, and some also have one grade of diesel fuel. Gas energy is measured in
# minimum octane ratings—87, 89, and 91—marked clearly on the pumps. Which grade should your car use?
# All gas-engine cars can operate using 87-octane gasoline, the least expensive grade. Some high-performance engines operate
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}
# ----------------------------------------
# Text 12:
# more efficiently with higher grade fuel. Your car’s owner’s manual will indicate which grade of gas the engine was designed
# to operate on. Alternately, use 87 octane unless the running engine has a pinging sound, called knocking, that may damage
# an engine. Then use higher octane fuel that doesn’t knock.
# Diesel is also a petroleum fuel, but not the same as gasoline. Don’t use diesel in a gas engine or vice versa. Note that No. 2
# diesel is pumped from a green nozzle.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}
# ----------------------------------------
# Text 13:
# diesel is pumped from a green nozzle.
# Checking Out Your Car While Working the Pump
# The best place to start getting to know your car is at the gas station. Take the time while the gas is
# pumping to distract yourself from the cost and spend some quality time with your car.
# What can you do at the pumps? You can select the most appropriate fuel for your car, check fluid
# levels, do a visual inspection, and make sure that all systems are “go” before pulling back onto the
# highway.
# Gas Station
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}
# ----------------------------------------
# Text 14:
# highway.
# Gas Station
# Wisdom
# CONTINUED ON NEXT PAGE
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 5}
# ----------------------------------------
# Text 15:
# 8
# POP THE HOOD
# For safety and security, the engine cover, called the hood (or
# bonnet in Britain), is latched into place. The hood release latch
# typically is located under the left side of the dashboard and is
# often marked HOOD.
# 1 Pull the hood lever inside the car.
# 2 Reach under the center of the partially opened hood and move
# the safety lever. (The car’s owner’s manual offers the specific
# location and instructions.)
# 3 Lift the hood and secure it in place. Many modern cars have a
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}
# ----------------------------------------
# Text 16:
# location and instructions.)
# 3 Lift the hood and secure it in place. Many modern cars have a
# metal support bar across the front of the engine compartment.
# Lift the bar into place and insert the end into the designated
# hole on the bottom side of the hood.
# 4 Check the levels of engine oil and other liquids as described
# later in this book.
# 5 Perform a visual inspection for any obvious liquid leaks, rodent nests, loose caps, or other potential problems.
# WALK AROUND
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}
# ----------------------------------------
# Text 17:
# WALK AROUND
# Once you’ve firmly closed the hood, walk around the car,
# inspecting the tires and underside for obvious problems or
# leaks. Inspect tires for wear, especially uneven wear, as
# described in Chapter 7 on suspension systems.
# Gas Station
# Wisdom (continued)
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 6}
# ----------------------------------------
# Text 18:
# chapter1
# Cars 101
# 9
# READ THE GAUGES
# Your car has numerous lights and gauges that continually report the condition of its components. To read them, start the car
# or turn the ignition to the ACCESSORIES position.
#  • Ammeter gauge or light reports on how well the battery is being recharged by the alternator.
#  • Temperature gauge or light tells you if the engine is operating too hot.
#  • Fuel gauge indicates the level of fuel in the tank(s).
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}
# ----------------------------------------
# Text 19:
# • Fuel gauge indicates the level of fuel in the tank(s).
# You will learn to read and interpret these gauges as well as the car’s computer in coming chapters.
# Check engine
# Tachometer
# Ammeter
# Odometer
# Credit: American Honda Corp.
# Fuel
# Temperature
# Oil
# Speedometer
# TIP
# Use Your Senses
# In addition to looking at your car, pay attention to smells under the hood. The smells of burned rub-
# ber or plastic or of leaking fuel are warning signs that can alert you to potential problems. Also, listen
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}
# ----------------------------------------
# Text 20:
# to your car when it’s running well so that you’ll recognize the sound when it doesn’t run well.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 7}
# ----------------------------------------
# Text 21:
# 10
# PREVENTIVE MAINTENANCE
# An important step in owning a trouble-free car—and minimizing costly work—is preventive maintenance. Replace oil, filters,
# and tires before they wear out and cause further damage. This book shows you how to perform basic preventive mainte-
# nance on your car step by step. Automotive maintenance is easy—when you know how.
# OBSERVE
# Modern cars are easier to drive; however, drivers today also have more
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}
# ----------------------------------------
# Text 22:
# OBSERVE
# Modern cars are easier to drive; however, drivers today also have more
# distractions, such as cell phones, GPS, and the radio. Beginning at the gas
# station and continuing every mile that you drive, pay close attention to
# your car. As you learn more about how it works in this book, you’ll detect
# more of the telltale signs that indicate what is expected and what is a
# potential problem.
# Knowing Your Car’s Needs
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}
# ----------------------------------------
# Text 23:
# potential problem.
# Knowing Your Car’s Needs
# The complexity of cars over the past century, such as computer-controlled electrical systems, makes
# taking things apart and repairing them more difficult.
# Fortunately, you don’t have to rebuild a component anymore. It’s easier—and often cheaper—
# to simply replace the part. In fact, that’s what auto mechanics usually do. They replace rather than
# repair defective parts, and so can you, which is the secret of modern auto repair.
# The Secret of
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}
# ----------------------------------------
# Text 24:
# repair defective parts, and so can you, which is the secret of modern auto repair.
# The Secret of
# Auto Repair
# REPLACE
# Replacing a defective part can be a relatively simple job, depending on
# how difficult it is to get to the problem part. Many automotive parts can be
# replaced by any car owner. Others require additional instruction from this
# book or a specific-model repair manual. Still others are most efficiently
# replaced by a trained mechanic who has the tools and knowledge to
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}
# ----------------------------------------
# Text 25:
# replaced by a trained mechanic who has the tools and knowledge to
# make a difficult job look easy. This book helps you identify what you can
# replace and what you can’t.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 8}
# ----------------------------------------
# Text 26:
# chapter1
# Cars 101
# 11
# TROUBLESHOOT
# Troubleshooting is simply comparing what you see to what you expect to
# see, and then using your knowledge to identify the cause. For example, you
# observe that the engine doesn’t start as easily on mornings after it hasn’t
# been driven for a few days. Knowing how cars work, you believe that a
# slow leak in a fuel line is robbing the engine of needed fuel when it starts
# up. A quick inspection confirms your observation and you have solved the
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 27:
# up. A quick inspection confirms your observation and you have solved the
# problem—and saved yourself some money and future problems.
# TIP
# Troubleshooting Charts
# A troubleshooting chart can save you hours of
# work and many dollars in replacement parts by
# helping you identify the source of an automo-
# tive problem. Your car’s repair manual includes
# troubleshooting tips specific to the make,
# model, design, and components of your car. If
# the chart indicates more than one option, per-
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 28:
# model, design, and components of your car. If
# the chart indicates more than one option, per-
# form the easiest or least expensive before trying
# the others.
# STEERING SYSTEM PROBLEMS
# CONDITION
# Power
# steering
# pump leaks.
# Noise in
# steering
# column.
# (Squeak
# or creak)
# (Clunk)
# Excessive
# Steering
# Eﬀort
# 1. Fluid, cap and dipstick.
# 1. Check for indications of false leakage —
# overﬁlled reservoir, improperly installed,
# damaged or lost cap or dipstick.
# 2. Loose or damaged hose connections.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 29:
# damaged or lost cap or dipstick.
# 2. Loose or damaged hose connections.
# 2. Repair or replace as required.
# 3. Leakage between reservoir and housing.
# 3. Repair or replace as required.
# 4. Leakage at pump shaft seal area.
# 4. Replace shaft seal or pump.
# 1. Steering column cover interference.
# 1.  Adjust or reposition as required.
# 2. Steering column out of alignment.
# 2. Align or adjust as required.
# 3. Lack of lubrication where horn brush contacts rub
# plate of steering wheel.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 30:
# 3. Lack of lubrication where horn brush contacts rub
# plate of steering wheel.
# 3. Lube or adjust as required.
# 4. Loose steering column mounting bolts.
# 4. Tighten to speciﬁcation.
# 5. Flex coupling bottoming.
# 5. Align or adjust as required.
# 6. Loose pot coupling to steering column bolt.
# 6. Tighten to speciﬁcation.
# 7. Improper steering gear mesh load.
# 7. Readjust to speciﬁcation.
# 1. Improper oversized tires.
# 1. Install correct tire and wheel combination.
# 2. Tires not uniform.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 31:
# 1. Improper oversized tires.
# 1. Install correct tire and wheel combination.
# 2. Tires not uniform.
# 2. Install correct tire and wheel combination.
# 3. Tire pressure.
# 3. Adjust air pressure in tires.
# 4. Misaligned ﬂexible coupling (if so equipped) to
# gear interference.
# 4. Align or adjust as required.
# 5. Steering wheel to column interference.
# 5. Align or adjust as required.
# 6.  Steering column alignment
# 6. Align or adjust as required (E-150 — E-350).
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 32:
# 6.  Steering column alignment
# 6. Align or adjust as required (E-150 — E-350).
# 7. Steering linkage or front axle spindle pins for a
# binding condition or lack of lubrication.
# 7.  Lube, inspect, adjust o replace as required.
# 8. Bind in front axle spindle thrust bearings.
# 8. Lube, inspect, adjust or replace as required.
# 9. Steering gear adjustment.
# 9. Adjust to speciﬁcation.
# POSSIBLE CAUSE
# RESOLUTION
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 9}
# ----------------------------------------
# Text 33:
# 12
# KNOWLEDGE
# The primary difference between you and a $90+-an-hour auto mechanic is knowledge. The mechanic has gone to school to
# learn about how cars run, diagnostics, and parts replacement. You can pick up the knowledge needed for basic car care and
# maintenance from this book. With experience, you may decide to tackle increasingly complex repairs on your car. Car care
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}
# ----------------------------------------
# Text 34:
# isn’t an all-or-nothing task. You can do the jobs that you are comfortable with and leave the heavy lifting to your well-chosen
# mechanic.
# TOOLS
# Another clear difference between
# mechanics and the typical car owner is
# tools. A mechanic or repair shop has
# thousands of dollars invested in special-
# ized tools and diagnostic equipment,
# while the owner may have a $50 tool-
# box. Fortunately, you often can rent
# more expensive tools for difficult jobs.
# The bottom line is that you have
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}
# ----------------------------------------
# Text 35:
# more expensive tools for difficult jobs.
# The bottom line is that you have
# options. You can take better care of
# your car—and be ready to handle prob-
# lems—by learning more about your car
# and performing increasingly difficult
# jobs.
# Intimidated by the complexity of taking care of your car? Don’t be. Owners have been successfully
# maintaining and repairing their cars for decades. In a couple of pages, you’ll learn how trouble-
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}
# ----------------------------------------
# Text 36:
# maintaining and repairing their cars for decades. In a couple of pages, you’ll learn how trouble-
# shooting and making repairs is even easier than it was two decades ago. You just need knowledge
# and the proper tools.
# Do-It-Yourself
# or Not?
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 10}
# ----------------------------------------
# Text 37:
# chapter1
# Cars 101
# 13
# Start looking for a fair and competent
# mechanic as you take on more respon-
# sibility for the care of your car. As you
# learn more about how your car operates
# and how to diagnose problems, you’ll
# also learn more about mechanics. The
# more you know about how your car
# works, the easier it will be to recognize
# a trustworthy mechanic. You’ll discover
# that most are specialized: One who may
# be specially trained in automatic trans-
# missions probably doesn’t know as
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}
# ----------------------------------------
# Text 38:
# be specially trained in automatic trans-
# missions probably doesn’t know as
# much about fuel injection systems.
# The National Institute for Automotive
# Service Excellence (ASE) and other trade
# groups offer courses and certification
# tests for automotive technicians and
# parts clerks. An ASE mechanic who is
# certified in all car systems earns the
# Master Mechanic designation. Of course,
# if you need only a qualified transmission
# mechanic, you can select one with ASE
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}
# ----------------------------------------
# Text 39:
# if you need only a qualified transmission
# mechanic, you can select one with ASE
# certification in transmissions rather than one who does all repairs. Also, some repair shops earn AAA approval.
# Knowing When You’ve Found “The One”
# Where is a qualified and honest mechanic when you need one? Well, the best time to find one is
# when you don’t need one and when your car doesn’t have an emergency that needs to be taken
# care of.
# Finding a
# Mechanic
# TIP
# Compare Shop Rates
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}
# ----------------------------------------
# Text 40:
# care of.
# Finding a
# Mechanic
# TIP
# Compare Shop Rates
# Many auto mechanics estimate the
# time required to complete a repair by
# using recommendations in a flat rate
# manual. They multiply the time esti-
# mate by their hourly shop rate to
# determine the labor rate. The higher
# the shop rate, the more expensive the
# labor charge will be.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 11}
# ----------------------------------------
# Text 41:
# 14
# WHAT IS OBD-II?
# All new cars, light trucks, SUVs, and minivans sold in North
# America since 1996 are required to have a connection for on-
# board diagnostics (OBD). The second version, OBD-II, has
# been the standard for more than a decade. Europe has had
# EOBD for new gasoline cars since 2001 and diesel cars since
# 2004.
# OBD-readers plug into a connection on the vehicle, read the
# computer data, and report parameter identification numbers
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}
# ----------------------------------------
# Text 42:
# computer data, and report parameter identification numbers
# (PIDs). These PIDs can be decoded. P1456, for example, indi-
# cates that an EVAP system leak is detected in the fuel tank
# area. In plain English, the gas cap is loose. Mechanics have
# been using on-board diagnostics readers for many years.
# OBD-II
# Wouldn’t it be great if you could read the mind of your car’s computer, just like your mechanic does
# with engine-analysis tools? You can!
# Car Computer
# Basics
# FINDING OBD-II DIAGNOSTICS TOOLS
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}
# ----------------------------------------
# Text 43:
# with engine-analysis tools? You can!
# Car Computer
# Basics
# FINDING OBD-II DIAGNOSTICS TOOLS
# The good news for consumers is that handheld OBD-II diag-
# nostics tools are now available for less than $100! One popu-
# lar version is the CarMD (www.carmd.com). With the included
# instructions and software, car owners can read and interpret
# the car’s diagnostics system. You can use these handy tools to:
#  • Quickly diagnose problems during an emergency.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}
# ----------------------------------------
# Text 44:
# • Quickly diagnose problems during an emergency.
#  • Discuss an automotive problem more accurately with
# your mechanic.
#  • Verify the findings of your mechanic.
#  • Check your car for problems before taking it in for a
# state-required smog test.
#  • Check cars and light trucks you are considering for pur-
# chase.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 12}
# ----------------------------------------
# Text 45:
# chapter1
# Cars 101
# 15
# USING THE OBD-II
# There are four simple steps to using a consumer-level OBD-II
# diagnostics tool:
# 1 Insert the data link connector (DLC) into the car’s receptacle.
# (Check your car owner’s manual for the DLC location.)
# 2 Within 10 seconds, turn the ignition key to the  (not )
# position.
# 3 Wait for the data download to complete.
# 4 Refer to the tool’s printed documentation, computer software,
# or website to decode the data.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}
# ----------------------------------------
# Text 46:
# 4 Refer to the tool’s printed documentation, computer software,
# or website to decode the data.
# Chapter 5 offers more detailed steps for using a consumer
# OBD-II diagnostics tool. Also refer to instructions that come
# with the unit.
# FAQ
# How can I know for sure if my
# car’s computer can be read by
# OBD-II analyzers?
# All 1996 and newer vehicles are
# required to be OBD-II (also known as
# OBD2) compliant. In addition, some
# 1994 and 1995 cars can be read by
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}
# ----------------------------------------
# Text 47:
# OBD2) compliant. In addition, some
# 1994 and 1995 cars can be read by
# OBD-II analyzers. To verify, open your
# car’s hood and look for the VEHICLE
# EMISSION CONTROL INFORMATION label
# located on the underside of the hood
# or near the radiator. If it is compliant,
# the label will say “OBD-II Certified.”
# Some light-duty diesel pickup trucks
# and recreational vehicles (RVs) also
# are OBD-II certified.
# Metadata: {'producer': 'Acrobat Distiller 6.0.1 (Windows)', 'creator': 'Adobe InDesign CS3 (5.0.3)', 'creationdate': '2009-01-30T20:33:37-05:00', 'source': 'car101.pdf', 'file_path': 'car101.pdf', 'total_pages': 14, 'format': 'PDF 1.3', 'title': '03_377277-ch01.indd', 'author': 'jturner', 'subject': '', 'keywords': '', 'moddate': "D:20090515084136-04'", 'trapped': '', 'modDate': "D:20090515084136-04'", 'creationDate': "D:20090130203337-05'00'", 'page': 13}
# ----------------------------------------
